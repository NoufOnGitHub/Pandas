# %% [markdown]
# (1) Load 3 Datasets of choice from UCI

# %%
import pandas as pd

# %%
df1 = pd.read_csv('name_gender_dataset.csv')

# %%
df1
# Out:
#            Name Gender    Count   Probability
# 0         James      M  5304407  1.451679e-02
# 1          John      M  5260831  1.439753e-02
# 2        Robert      M  4970386  1.360266e-02
# 3       Michael      M  4579950  1.253414e-02
# 4       William      M  4226608  1.156713e-02
# ...         ...    ...      ...           ...
# 147264   Zylenn      M        1  2.736740e-09
# 147265   Zymeon      M        1  2.736740e-09
# 147266   Zyndel      M        1  2.736740e-09
# 147267   Zyshan      M        1  2.736740e-09
# 147268    Zyton      M        1  2.736740e-09
#
# [147269 rows x 4 columns]

# %%
df2 = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv')

# %%
df2
# Out:
#                                                                     Bejaia Region Dataset
# day month year Temperature  RH  Ws Rain  FFMC DMC DC   ISI BUI  FWI              Classes
# 01  06    2012 29          57  18  0     65.7 3.4 7.6  1.3 3.4  0.5            not fire
# 02  06    2012 29          61  13  1.3   64.4 4.1 7.6  1   3.9  0.4            not fire
# 03  06    2012 26          82  22  13.1  47.1 2.5 7.1  0.3 2.7  0.1            not fire
# 04  06    2012 25          89  13  2.5   28.6 1.3 6.9  0   1.7  0              not fire
# ...                                                                                    ...
# 26  09    2012 30          65  14  0     85.4 16  44.5 4.5 16.9 6.5                fire
# 27  09    2012 28          87  15  4.4   41.1 6.5 8    0.1 6.2  0              not fire
# 28  09    2012 27          87  29  0.5   45.9 3.5 7.9  0.4 3.4  0.2            not fire
# 29  09    2012 24          54  18  0.1   79.7 4.3 15.2 1.7 5.1  0.7            not fire
# ...

# %%
df3 = pd.read_excel('2014 and 2015 CSM dataset.xlsx')

# %%
df3
# Out:
#                       Movie  Year  Ratings  Genre      Gross       Budget  \
# 0                   13 Sins  2014      6.3      8       9130    4000000.0
# 1            22 Jump Street  2014      7.1      1  192000000   50000000.0
# 2            3 Days to Kill  2014      6.2      1   30700000   28000000.0
# 3    300: Rise of an Empire  2014      6.3      1  106000000  110000000.0
# 4         A Haunted House 2  2014      4.7      8   17300000    3500000.0
# ..                      ...   ...      ...    ...        ...          ...
# 226                Child 44  2015      6.4      4    1210000   50000000.0
# 227                   Aloha  2015      5.5     15   21000000   37000000.0
# 228     Unfinished Business  2015      5.4      8   10200000   35000000.0
# 229                War Room  2015      5.4      1   12300000    3000000.0
# 230             The Gallows  2015      4.4     15   22600000     100000.0
#
#      Screens  Sequel  Sentiment    Views  Likes  Dislikes  Comments  \
# ...

# %% [markdown]
# (2) What each column in df3 means

# %% [markdown]
# Year:year at which movies were projected on the screens.
#
# Ratings: ratings.
#
# Genre: genre of the movie.
#
# Gross: gross income in USD.
#
# Budget: budget in USD.
#
# Screens: number of screens in USA.
#
# Sequel: how many sequels (if any) does the movie has.
#
# Sentiment: sentiment score.
#
# Views: number of views of movie trailer on Youtube.
#
# Likes: number of likes of movie trailer on Youtube.
#
# Dislikes: number of dislikes of movie trailer on Youtube.
#
# Comments: number of comments of movie trailer on Youtube.
#
# Aggregate.Followers: aggregate actor followers on Twitter.
